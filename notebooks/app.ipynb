# %%
import requests
import pandas as pd
from numpy import nan

# %run classes.ipynb
# %run functions.ipynb

# %%
from app.plans.models import EducationPlan

plan = EducationPlan(133)
# matrix = CompMatrix('40.03.02 Обеспечение законности и правопорядка (Ответы).xlsx')

# %%
plan.disciplines  # Получение списка дисциплин плана
# Out:
# {'10463': ['Б.1.О.34',
#   'Делопроизводство и режим секретности в органах внутренних дел'],
#  '10464': ['Б.1.О.35', 'Основы управления в органах внутренних дел'],
#  '10465': ['Б.1.В.ЭД.3.02',
#   'Обеспечение прав человека в деятельности органов внутренних дел'],
#  '10466': ['Б.1.О.25', 'Криминология'],
#  '10550': ['Б.1.О.38', 'Административная деятельность полиции']}

# %%
plan.competencies  # Получение списка компетенций плана
# Out:
# [{'id': '4115',
#   'education_plan_id': '133',
#   'code': 'УК-1',
#   'description': 'Способен осуществлять поиск, критический анализ и синтез информации, применять системный подход для решения поставленных задач',
#   'level': '1',
#   'left_node': '1',
#   'right_node': '2'},
#  {'id': '4116',
#   'education_plan_id': '133',
#   'code': 'УК-2',
#   'description': 'Способен определять круг задач в рамках поставленной цели и выбирать оптимальные способы их решения, исходя из действующих правовых норм, имеющихся ресурсов и ограничений',
#   'level': '1',
#   'left_node': '3',
#   'right_node': '4'},
#  {'id': '4117',
#   'education_plan_id': '133',
#   'code': 'УК-3',
#   'description': 'Способен осуществлять социальное взаимодействие и реализовывать свою роль в команде',
#   'level': '1',
#   'left_node': '5',
#   'right_node': '6'},
#  {'id': '4118',
#   'education_plan_id': '133',
#   'code': 'УК-4',
#   'description': 'Способен осуществлять деловую коммуникацию в устной и письменной формах на государственном языке Российской Федерации и иностранном(ых) языке(ах)',
#   'level': '1',
#   'left_node': '7',
#   'right_node': '8'},
#  {'id': '4119',
#   'education_plan_id': '133',
#   'code': 'УК-5',
#   'description': 'Способен воспринимать межкультурное разнообразие общества в социально-историческом, этическом и философском контекстах',
#   'level': '1',
#   'left_node': '9',
#   'right_node': '10'},
#  {'id': '4120',
#   'education_plan_id': '133',
#   'code': 'УК-6',
#   'description': 'Способен управлять своим временем, выстраивать и реализовывать траекторию саморазвития на основе принципов образования в течение всей жизни',
#   'level': '1',
#   'left_node': '11',
#   'right_node': '12'},
#  {'id': '4121',
#   'education_plan_id': '133',
#   'code': 'УК-7',
#   'description': 'Способен поддерживать должный уровень физической подготовленности для обеспечения полноценной социальной и профессиональной деятельности',
#   'level': '1',
#   'left_node': '13',
#   'right_node': '14'},
#  {'id': '4122',
#   'education_plan_id': '133',
#   'code': 'УК-8',
#   'description': 'Способен создавать и поддерживать в повседневной жизни и в профессиональной деятельности безопасные условия жизнедеятельности для сохранения природной среды, обеспечения устойчивого развития общества, в том числе при угрозе и возникновении чрезвычайных ситуаций и военных конфликтов',
#   'level': '1',
#   'left_node': '15',
#   'right_node': '16'},
#  {'id': '4123',
#   'education_plan_id': '133',
#   'code': 'УК-9',
#   'description': 'Способен использовать базовые дефектологические знания в социальной и профессиональной сферах',
#   'level': '1',
#   'left_node': '17',
#   'right_node': '18'},
#  {'id': '4124',
#   'education_plan_id': '133',
#   'code': 'УК-10',
#   'description': 'Способен принимать обоснованные экономические решения в различных областях жизнедеятельности',
#   'level': '1',
#   'left_node': '19',
#   'right_node': '20'},
#  {'id': '4125',
#   'education_plan_id': '133',
#   'code': 'УК-11',
#   'description': 'Способен формировать нетерпимое отношение к коррупционному поведению',
#   'level': '1',
#   'left_node': '21',
#   'right_node': '22'},
#  {'id': '4126',
#   'education_plan_id': '133',
#   'code': 'ОПК-1',
#   'description': 'Способен на основе анализа особенностей развития Российского государства, его места в истории человечества формировать мотивы профессионально-служебной деятельности, основанной на патриотизме, ответственном отношении к выполнению профессионального долга',
#   'level': '1',
#   'left_node': '23',
#   'right_node': '24'},
#  {'id': '4127',
#   'education_plan_id': '133',
#   'code': 'ОПК-2',
#   'description': 'Способен формировать ценностно-мотивационные этические основы профессионально-служебной деятельности на базе гуманитарного мировоззрения, духовных ценностей',
#   'level': '1',
#   'left_node': '25',
#   'right_node': '26'},
#  {'id': '4128',
#   'education_plan_id': '133',
#   'code': 'ОПК-3',
#   'description': 'Способен применять основные общеправовые понятия и категории, анализировать и толковать нормы права, давать юридическую оценку фактам и обстоятельствам',
#   'level': '1',
#   'left_node': '27',
#   'right_node': '28'},
#  {'id': '4129',
#   'education_plan_id': '133',
#   'code': 'ОПК-4',
#   'description': 'Способен составлять процессуальные и служебные документы в контексте своей профессиональной деятельности',
#   'level': '1',
#   'left_node': '29',
#   'right_node': '30'},
#  {'id': '4130',
#   'education_plan_id': '133',
#   'code': 'ОПК-5',
#   'description': 'Способен реализовывать нормы материального и процессуального права в сфере профессиональной деятельности, принимать юридические решения в соответствии с законодательством Российской Федерации',
#   'level': '1',
#   'left_node': '31',
#   'right_node': '32'},
#  {'id': '4131',
#   'education_plan_id': '133',
#   'code': 'ОПК-6',
#   'description': 'Способен выполнять должностные обязанности по обеспечению законности и правопорядка, охране общественного порядка при соблюдении норм права и нетерпимости к противоправному поведению',
#   'level': '1',
#   'left_node': '33',
#   'right_node': '34'},
#  {'id': '4132',
#   'education_plan_id': '133',
#   'code': 'ОПК-7',
#   'description': 'Способен выявлять, пресекать преступления и иные правонарушения, принимать меры к установлению и задержанию правонарушителей',
#   'level': '1',
#   'left_node': '35',
#   'right_node': '36'},
#  {'id': '4133',
#   'education_plan_id': '133',
#   'code': 'ОПК-8',
#   'description': 'Способен применять криминалистические средства, методы и приемы в профессиональной деятельности',
#   'level': '1',
#   'left_node': '37',
#   'right_node': '38'},
#  {'id': '4134',
#   'education_plan_id': '133',
#   'code': 'ОПК-9',
#   'description': 'Способен правомерно и эффективно применять и использовать в профессиональной деятельности табельное оружие, физическую силу, специальные средства и специальную технику, применяемые в деятельности правоохранительных органов, по линии которых осуществляется подготовка кадров, оказывать первую помощь, обеспечивать личную безопасность и безопасность граждан в процессе решения служебных задач',
#   'level': '1',
#   'left_node': '39',
#   'right_node': '40'},
#  {'id': '4135',
#   'education_plan_id': '133',
#   'code': 'ОПК-10',
#   'description': 'Способен применять методы психической регуляции для оптимизации собственной деятельности и психического состояния, в том числе в сложных и экстремальных условиях, решать профессионально-служебные задачи с использованием психологических методов, средств и приемов',
#   'level': '1',
#   'left_node': '41',
#   'right_node': '42'},
#  {'id': '4136',
#   'education_plan_id': '133',
#   'code': 'ОПК-11',
#   'description': 'Способен осуществлять профилактику, предупреждение правонарушений, выявлять и обеспечивать устранение причин и условий, способствующих их совершению',
#   'level': '1',
#   'left_node': '43',
#   'right_node': '44'},
#  {'id': '4137',
#   'education_plan_id': '133',
#   'code': 'ОПК-12',
#   'description': 'Способен понимать принципы работы современных информационных технологий и использовать их для решения задач профессиональной деятельности',
#   'level': '1',
#   'left_node': '45',
#   'right_node': '46'},
#  {'id': '4138',
#   'education_plan_id': '133',
#   'code': 'ПК-1',
#   'description': 'Способен соблюдать и защищать права и свободы человека и гражданина, принимать меры к их реализации и восстановлению нарушенных прав',
#   'level': '1',
#   'left_node': '47',
#   'right_node': '48'},
#  {'id': '4139',
#   'education_plan_id': '133',
#   'code': 'ПК-2',
#   'description': 'Способен выполнять профессиональные задачи в особых условиях, чрезвычайных обстоятельствах, чрезвычайных ситуациях, условиях режима чрезвычайного положения и в военное время',
#   'level': '1',
#   'left_node': '49',
#   'right_node': '50'},
#  {'id': '4140',
#   'education_plan_id': '133',
#   'code': 'ПК-3',
#   'description': 'Способен решать задачи профессиональной служебной деятельности по выявлению, предупреждению, пресечению и раскрытию преступлений и иных правонарушений, в том числе совершаемых с использованием информационно-телекоммуникационных технологий',
#   'level': '1',
#   'left_node': '51',
#   'right_node': '52'},
#  {'id': '4141',
#   'education_plan_id': '133',
#   'code': 'ПК-4',
#   'description': 'Способен применять физическую силу, специальные средства и огнестрельное оружие в случаях и порядке, предусмотренных Федеральным законом от 7 февраля 2011 г.  № 3-ФЗ «О полиции», и документировать их применение',
#   'level': '1',
#   'left_node': '53',
#   'right_node': '54'},
#  {'id': '4142',
#   'education_plan_id': '133',
#   'code': 'ПК-5',
#   'description': 'Способен применять специальную технику, средства видеонаблюдения, средства связи в профессиональной служебной деятельности',
#   'level': '1',
#   'left_node': '55',
#   'right_node': '56'},
#  {'id': '4143',
#   'education_plan_id': '133',
#   'code': 'ПК-6',
#   'description': 'Способен обеспечивать личную безопасность и безопасность граждан в повседневной профессиональной служебной деятельности',
#   'level': '1',
#   'left_node': '57',
#   'right_node': '58'},
#  {'id': '4144',
#   'education_plan_id': '133',
#   'code': 'ПК-7',
#   'description': 'Способен принимать обоснованные решения при обнаружении взрывоопасных предметов',
#   'level': '1',
#   'left_node': '59',
#   'right_node': '60'},
#  {'id': '4145',
#   'education_plan_id': '133',
#   'code': 'ПК-8',
#   'description': 'Способен поддерживать должный уровень физической готовности, необходимый для осуществления профессиональной служебной деятельности',
#   'level': '1',
#   'left_node': '61',
#   'right_node': '62'},
#  {'id': '4146',
#   'education_plan_id': '133',
#   'code': 'ПК-9',
#   'description': 'Способен выполнять неполную разборку и сборку, чистку табельного огнестрельного оружия, обеспечивать его сбережение',
#   'level': '1',
#   'left_node': '63',
#   'right_node': '64'},
#  {'id': '4147',
#   'education_plan_id': '133',
#   'code': 'ПК-10',
#   'description': 'Способен ориентироваться на местности с картой и без нее, использовать современные средства навигации',
#   'level': '1',
#   'left_node': '65',
#   'right_node': '66'},
#  {'id': '4148',
#   'education_plan_id': '133',
#   'code': 'ПК-11',
#   'description': 'Способен оказывать первую помощь и самопомощь, принимать меры по эвакуации пострадавших и их транспортировке',
#   'level': '1',
#   'left_node': '67',
#   'right_node': '68'},
#  {'id': '4149',
#   'education_plan_id': '133',
#   'code': 'ПК-12',
#   'description': 'Способен использовать в профессиональной служебной деятельности компьютерную технику, специализированное программное обеспечение, в том числе для работы с банками данных МВД России (информационно-правовыми, автоматизированными, информационными и иными системами), выполнять требования информационной безопасности',
#   'level': '1',
#   'left_node': '69',
#   'right_node': '70'},
#  {'id': '4150',
#   'education_plan_id': '133',
#   'code': 'ПК-13',
#   'description': 'Способен соблюдать правила работы со служебными документами и режим секретности',
#   'level': '1',
#   'left_node': '71',
#   'right_node': '72'},
#  {'id': '4151',
#   'education_plan_id': '133',
#   'code': 'ПК-14',
#   'description': 'Способен осуществлять с позиции профессиональной этики и морали выбор норм поведения в конкретных служебных ситуациях; давать нравственную оценку коррупционным проявлениям и другим нарушениям норм профессиональной этики; взаимодействовать с гражданами с учетом этнокультурных и конфессиональных различий; соблюдать правила вежливости и культуры поведения в профессиональной служебной деятельности, нормы и правила служебного этикета',
#   'level': '1',
#   'left_node': '73',
#   'right_node': '74'},
#  {'id': '4152',
#   'education_plan_id': '133',
#   'code': 'ПК-15',
#   'description': 'Способен применять приемы диагностики личности по внешним признакам, характерологическим и поведенческим особенностям, в том числе выявлять по внешним признакам лиц, вынашивающих преступные замыслы, планирующих совершение террористических актов и экстремистских действий',
#   'level': '1',
#   'left_node': '75',
#   'right_node': '76'},
#  {'id': '4153',
#   'education_plan_id': '133',
#   'code': 'ПК-16',
#   'description': 'Способен осуществлять профессиональную коммуникацию, психологически правильно строить общение с коллегами в служебном коллективе и с различными категориями граждан, применять приемы установления и поддержания психологического контакта, применять способы предотвращения и позитивного разрешения конфликтов, вести переговоры, применять приемы психологического воздействия',
#   'level': '1',
#   'left_node': '77',
#   'right_node': '78'},
#  {'id': '4154',
#   'education_plan_id': '133',
#   'code': 'ПК-17',
#   'description': 'Способен использовать приемы психологической саморегуляции, профилактики негативных последствий профессионального стресса',
#   'level': '1',
#   'left_node': '79',
#   'right_node': '80'},
#  {'id': '4155',
#   'education_plan_id': '133',
#   'code': 'ПК-18',
#   'description': 'Способен грамотно использовать в своей деятельности профессиональную лексику, владеть основами ораторского искусства',
#   'level': '1',
#   'left_node': '81',
#   'right_node': '82'},
#  {'id': '4156',
#   'education_plan_id': '133',
#   'code': 'ПК-19',
#   'description': 'Способен осуществлять контроль за наличием у водителей документов, предусмотренных Правилами дорожного движения',
#   'level': '1',
#   'left_node': '83',
#   'right_node': '84'},
#  {'id': '4157',
#   'education_plan_id': '133',
#   'code': 'ПК-20',
#   'description': 'Способен грамотно применять измерительное оборудование при проверке габаритных параметров сопровождаемых транспортных средств',
#   'level': '1',
#   'left_node': '85',
#   'right_node': '86'},
#  {'id': '4158',
#   'education_plan_id': '133',
#   'code': 'ПК-21',
#   'description': 'Способен осуществлять идентификацию транспортного средства, проверку (выявлять признаки изменения (несоответствия) идентификационного номера транспортного средства либо идентификационного номера основного компонента транспортного средства, соответствия конструкции транспортного средства, государственных регистрационных знаков, технического состояния транспортных средств, в том числе с использованием соответствующего оборудования',
#   'level': '1',
#   'left_node': '87',
#   'right_node': '88'},
#  {'id': '4159',
#   'education_plan_id': '133',
#   'code': 'ПК-22',
#   'description': 'Способен принимать меры по розыску угнанных и похищенных транспортных средств, а также транспортных средств, водители которых скрылись с места дорожно-транспортного происшествия',
#   'level': '1',
#   'left_node': '89',
#   'right_node': '90'},
#  {'id': '4160',
#   'education_plan_id': '133',
#   'code': 'ПК-23',
#   'description': 'Способен ограничивать или временно запрещать движение транспортных средств и пешеходов на дорогах, а также не допускать граждан и транспортные средства на отдельные участки местности и объекты, обязывать их остаться там или покинуть эти участки и объекты в целях защиты здоровья, жизни и имущества граждан при проведении следственных и розыскных действий',
#   'level': '1',
#   'left_node': '91',
#   'right_node': '92'},
#  {'id': '4161',
#   'education_plan_id': '133',
#   'code': 'ПК-24',
#   'description': 'Способен осуществлять регулирование дорожного движения, в том числе посредством применения распорядительно-регулировочных действий с использованием: сигналов регулировщика, ручного управления светофорным объектом, установки временных дорожных знаков и указателей, ограждения участка дороги техническими средствами организации дорожного движения, размещения на проезжей части патрульного автомобиля с включенными специальными световыми и звуковыми сигналами, громкоговорящего устройства; осуществлять остановку транспортного средства, остановку пешехода',
#   'level': '1',
#   'left_node': '93',
#   'right_node': '94'},
#  {'id': '4162',
#   'education_plan_id': '133',
#   'code': 'ПК-25',
#   'description': 'Способен правильно квалифицировать деяния лиц, совершивших правонарушения, при осуществлении производства по делам об административных правонарушениях',
#   'level': '1',
#   'left_node': '95',
#   'right_node': '96'},
#  {'id': '4163',
#   'education_plan_id': '133',
#   'code': 'ПК-26',
#   'description': 'Способен квалифицированно и грамотно осуществлять процессуальные действия по обнаружению, сохранению и фиксации следов правонарушения, установлению лиц, допустивших правонарушения в области дорожного движения, оформлять процессуальные документы',
#   'level': '1',
#   'left_node': '97',
#   'right_node': '98'},
#  {'id': '4164',
#   'education_plan_id': '133',
#   'code': 'ПК-27',
#   'description': 'Способен применять специальные технические средства для обнаружения, выявления и фиксации правонарушений, составлять необходимые процессуальные материалы',
#   'level': '1',
#   'left_node': '99',
#   'right_node': '100'},
#  {'id': '4165',
#   'education_plan_id': '133',
#   'code': 'ПК-28',
#   'description': 'Способен использовать в соответствии с законодательными и иными нормативными правовыми актами Российской Федерации федеральные учеты, информационные системы (банки данных оперативно-справочной, розыскной, криминалистической, статистической и иной информации), в том числе посредством удаленного доступа в процессе производства по делам об административных правонарушениях',
#   'level': '1',
#   'left_node': '101',
#   'right_node': '102'},
#  {'id': '4166',
#   'education_plan_id': '133',
#   'code': 'ПК-29',
#   'description': 'Способен применять меры обеспечения производства по делам об административных правонарушениях в области дорожного движения',
#   'level': '1',
#   'left_node': '103',
#   'right_node': '104'},
#  {'id': '4167',
#   'education_plan_id': '133',
#   'code': 'ПК-30',
#   'description': 'Способен осуществлять сбор доказательств и их оценку по своему внутреннему убеждению, основанному на всестороннем, полном и объективном исследовании всех обстоятельств дела в их совокупности, подготовку дел об административных правонарушениях для принятия решения вышестоящим должностным лицом',
#   'level': '1',
#   'left_node': '105',
#   'right_node': '106'},
#  {'id': '4168',
#   'education_plan_id': '133',
#   'code': 'ПК-31',
#   'description': 'Способен в пределах своей компетенции рассматривать и принимать решения по ходатайствам и жалобам лиц, участвующих в производстве по делу об административном правонарушении',
#   'level': '1',
#   'left_node': '107',
#   'right_node': '108'},
#  {'id': '4169',
#   'education_plan_id': '133',
#   'code': 'ПК-32',
#   'description': 'Способен осуществлять мероприятия по приему заявок на сопровождение транспортных колонн и транспортных средств, анализировать складывающуюся оперативную обстановку на маршруте сопровождения, реализовывать меры реагирования на ее изменение',
#   'level': '1',
#   'left_node': '109',
#   'right_node': '110'},
#  {'id': '4170',
#   'education_plan_id': '133',
#   'code': 'ПК-33',
#   'description': 'Способен осуществлять мероприятия, направленные на обеспечение сбора основных показателей состояния безопасности дорожного движения, а также их достоверности и полноты',
#   'level': '1',
#   'left_node': '111',
#   'right_node': '112'},
#  {'id': '4171',
#   'education_plan_id': '133',
#   'code': 'ПК-34',
#   'description': 'Способен осуществлять надзор за дорожным движением, в том числе с использованием специальных технических средств, работающих в автоматическом режиме и имеющих функции фото- и киносъемки, видеозаписи, для обеспечения контроля за дорожным движением',
#   'level': '1',
#   'left_node': '113',
#   'right_node': '114'},
#  {'id': '4172',
#   'education_plan_id': '133',
#   'code': 'ПК-35',
#   'description': 'Способен осуществлять федеральный государственный надзор и специальные разрешительные функции в области обеспечения безопасности дорожного движения',
#   'level': '1',
#   'left_node': '115',
#   'right_node': '116'},
#  {'id': '4173',
#   'education_plan_id': '133',
#   'code': 'ПК-36',
#   'description': 'Способен осуществлять защиту прав и представлять законные интересы Госавтоинспекции в пределах своей компетенции',
#   'level': '1',
#   'left_node': '117',
#   'right_node': '118'},
#  {'id': '4174',
#   'education_plan_id': '133',
#   'code': 'ПК-37',
#   'description': 'Способен осуществлять формирование автоматизированных учетов разыскиваемого автомототранспорта, утраченных, похищенных регистрационных и иных документов и спецпродукции Госавтоинспекции',
#   'level': '1',
#   'left_node': '119',
#   'right_node': '120'},
#  {'id': '4175',
#   'education_plan_id': '133',
#   'code': 'ПК-38',
#   'description': 'Способен оказывать предоставляемые органами Госавтоинспекции государственные услуги',
#   'level': '1',
#   'left_node': '121',
#   'right_node': '122'},
#  {'id': '4176',
#   'education_plan_id': '133',
#   'code': 'ПК-39',
#   'description': 'Способен использовать возможности средств массовой информации, информационно-телекоммуникационной сети «Интернет» по информированию населения о наиболее актуальных проблемных вопросах в области обеспечения безопасности дорожного движения, в том числе изменениях в законодательных актах, проведении мероприятий, направленных на обеспечение безопасности всех категорий участников дорожного движения',
#   'level': '1',
#   'left_node': '123',
#   'right_node': '124'},
#  {'id': '4177',
#   'education_plan_id': '133',
#   'code': 'ПК-40',
#   'description': 'Способен формировать негативное общественное мнение к нарушителям Правил дорожного движения Российской Федерации',
#   'level': '1',
#   'left_node': '125',
#   'right_node': '126'},
#  {'id': '4178',
#   'education_plan_id': '133',
#   'code': 'ПК-41',
#   'description': 'Способен вести работу по повышению культуры поведения и формированию правосознания участников дорожного движения',
#   'level': '1',
#   'left_node': '127',
#   'right_node': '128'},
#  {'id': '4179',
#   'education_plan_id': '133',
#   'code': 'ПК-42',
#   'description': 'Способен устанавливать степень соответствия обязательным требованиям безопасности транспортно-эксплуатационных характеристик и состояния автомобильных дорог, принимать меры к обозначению и ограждению опасных мест, составлять акт о выявленных недостатках в эксплуатационном состоянии автомобильной дороги (улицы), железнодорожного переезда',
#   'level': '1',
#   'left_node': '129',
#   'right_node': '130'},
#  {'id': '4180',
#   'education_plan_id': '133',
#   'code': 'ПК-43',
#   'description': 'Способен участвовать в качестве консультанта и рецензента в издании кино-видеопродукции, социальной рекламы, сценических постановок по безопасности дорожного движения, а также оказывать содействие в организации дальнейшего их использования',
#   'level': '1',
#   'left_node': '131',
#   'right_node': '132'},
#  {'id': '4181',
#   'education_plan_id': '133',
#   'code': 'ПК-44',
#   'description': 'Способен решать служебные задачи индивидуально и в составе нарядов, групп оперативно-служебного применения',
#   'level': '1',
#   'left_node': '133',
#   'right_node': '134'},
#  {'id': '4182',
#   'education_plan_id': '133',
#   'code': 'ПК-45',
#   'description': 'Способен взаимодействовать с представителями федеральных органов государственной власти, государственных органов субъектов Российской Федерации, органов местного самоуправления, иных организаций',
#   'level': '1',
#   'left_node': '135',
#   'right_node': '136'}]

# %%
plan.disciplines_comp()  # Получение связей дисциплин и компетенций
# Out:
# [{'curriculum_discipline_id': '10463', 'competency_id': '4128'},
#  {'curriculum_discipline_id': '10463', 'competency_id': '4129'},
#  {'curriculum_discipline_id': '10463', 'competency_id': '4150'},
#  {'curriculum_discipline_id': '10464', 'competency_id': '4115'},
#  {'curriculum_discipline_id': '10464', 'competency_id': '4116'},
#  {'curriculum_discipline_id': '10464', 'competency_id': '4117'},
#  {'curriculum_discipline_id': '10464', 'competency_id': '4137'},
#  {'curriculum_discipline_id': '10464', 'competency_id': '4139'},
#  {'curriculum_discipline_id': '10464', 'competency_id': '4140'},
#  {'curriculum_discipline_id': '10464', 'competency_id': '4149'},
#  {'curriculum_discipline_id': '10465', 'competency_id': '4125'},
#  {'curriculum_discipline_id': '10465', 'competency_id': '4130'},
#  {'curriculum_discipline_id': '10465', 'competency_id': '4138'},
#  {'curriculum_discipline_id': '10466', 'competency_id': '4115'},
#  {'curriculum_discipline_id': '10466', 'competency_id': '4127'},
#  {'curriculum_discipline_id': '10466', 'competency_id': '4128'},
#  {'curriculum_discipline_id': '10466', 'competency_id': '4130'},
#  {'curriculum_discipline_id': '10466', 'competency_id': '4131'},
#  {'curriculum_discipline_id': '10466', 'competency_id': '4136'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4115'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4116'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4117'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4122'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4128'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4129'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4130'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4131'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4132'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4136'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4138'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4139'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4141'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4142'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4143'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4156'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4166'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4167'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4168'},
#  {'curriculum_discipline_id': '10550', 'competency_id': '4181'}]

# %%
plan.disciplines_all_comp_del()  # Удаление всех связей дисциплин, компетенций и содержания из программ

# %%
plan.del_comp()  # Удаление всех компетенций плана
# Out:
# []

# %%
# Загрузка Компетенций из файла

df = pd.DataFrame(pd.read_excel('40-03-02-comp.xlsx', engine='openpyxl'))
# Normalize DataFrame
replace_dict = {'  ':' ', '–':'-', '. - ':' - ', 'K':'К', 'O':'О'}
for key, value in replace_dict.items():
    df[df.columns[0]] = df[df.columns[0]].str.replace(key, value, regex=False)

left_node, right_node  = 1, 2

for i in range(len(df)): #len(df)
    code = df.at[i, df.columns[0]]
    description = df.at[i, df.columns[1]]
    plan.load_comp(code, description, left_node, right_node)
    left_node += 2
    right_node += 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d5/4nwn2rys5sz573f88fj_4vfc0000gn/T/ipykernel_9317/2701970847.py in <module>
#       1 # Загрузка Компетенций из файла
#       2
# ----> 3 df = pd.DataFrame(pd.read_excel('40-03-02-comp.xlsx', engine='openpyxl'))
#       4 # Normalize DataFrame
#       5 replace_dict = {'  ':' ', '–':'-', '. - ':' - ', 'K':'К', 'O':'О'}
#
# NameError: name 'pd' is not defined

# %%
from openpyxl import load_workbook

# Загрузка Компетенций из файла

wb = load_workbook('comp_load_temp.xlsx')
ws = wb.active

# Normalize Data
replace_dict = {'  ':' ', '–':'-', '. - ':' - ', 'K':'К', 'O':'О'}
for key, val in replace_dict.items():
    for r in range(1, ws.max_row + 1):
        for c in range(1, 2):
            s = str(ws.cell(r, c).value)
            ws.cell(r, c).value = s.replace(key, val)

def iter_rows(ws):
    for row in ws.iter_rows():
        yield [cell.value for cell in row]
comps = list(iter_rows(ws))
del comps[0]

left_node, right_node  = 1, 2

for comp in comps:
    code = comp[0]
    description = comp[1]
    plan.load_comp(code, description, left_node, right_node)
    left_node += 2
    right_node += 2

# %%
matrix.df  # Данные из файла
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9368/2049814312.py in <module>
# ----> 1 matrix.df  # Данные из файла
#
# NameError: name 'matrix' is not defined

# %%
matrix.df_errors()  # Ошибки данных
# Out:
# ['Выберите дисциплину']

# %%
matrix.disc_check('Б.1.О.3 Экономика')  # Проверка есть ли дисциплина в матрице
# Out:
# True

# %%
matrix.disc_comp('Б.1.О.38 Административная деятельность полиции')  # Выгрузка компетенций и индикаторов по дисциплине
# Out:
# {'УК-1': {'knowledge': ['- сущность и основные принципы системного подхода к решению задач профессиональной деятельности, основные формы мышления, мыслительные операции, способы поиска информации (УК-1.з.1)'],
#   'abilities': ['- осуществлять поиск информации, необходимой для решения задач профессиональной деятельности; выделять главную информацию; подвергать сомнению достоверность информации (УК-1.у.1)',
#    '- выявлять закономерности и взаимосвязи; устанавливать объективную истину; обосновывать выбранные пути решения задач профессиональной деятельности (УК-1.у.3)'],
#   'ownerships': ['- способностью применять системный подход при решении проблемных ситуаций и выработке стратегии действий в профессиональной деятельности (УК-1.в.1)']},
#  'УК-2': {'knowledge': ['- способы постановки цели и определения в ее рамках круга задач (УК-2.з.2)'],
#   'abilities': ['- формулировать в рамках поставленной цели проекта совокупность взаимосвязанных задач, обеспечивающих ее достижение (УК-2.у.1)',
#    '- проектировать решение конкретной задачи проекта, выбирать оптимальный способ ее решения, исходя из действующих правовых норм и имеющихся ресурсов и ограничений (УК-2.у.3)'],
#   'ownerships': ['- способностью определять ожидаемые результаты решения выделенных задач (УК-2.в.1)',
#    '- навыками публично представлять результаты решения конкретной задачи проекта (УК-2.в.2)']},
#  'УК-3': {'knowledge': [],
#   'abilities': ['- эффективно взаимодействовать с другими членами команды, в том числе участвовать в обмене информацией, знаниями и опытом, и презентации результатов работы команды (УК-3.у.2)'],
#   'ownerships': ['- навыками эффективного использования стратегии сотрудничества для достижения поставленной цели, определения свей роли в команде (УК-3.в.1)']},
#  'УК-8': {'knowledge': ['- чрезвычайные ситуации; поражающие факторы и правила поведения при угрозе и возникновении чрезвычайных ситуаций и военных конфликтов; единую государственную систему предупреждения и ликвидации чрезвычайных ситуаций (УК-8.з.2)'],
#   'abilities': [],
#   'ownerships': []},
#  'ОПК-3': {'knowledge': ['- виды и способы толкования норм права, требования к процессу толкования норм права (ОПК-3.з.4)',
#    '- свойства юридических фактов и особенности возникающих на их основе правоотношений (ОПК-3.з.5)'],
#   'abilities': ['- оперировать юридическими понятиями, категориями и терминами в процессе осуществления своей профессиональной и служебной деятельности (ОПК-3.у.1)',
#    '- толковать нормы права, устанавливать их действительный смысл и значение в системе права (ОПК-3.у.4)',
#    '- выявлять юридически значимые фактические данные и обстоятельства, анализировать юридические факты и возникающие в связи с ними правовые отношения, давать правовую квалификацию выявленным фактам и обстоятельствам в сфере своей профессиональной и служебной деятельности (ОПК-3.у.5)'],
#   'ownerships': ['- навыками использования категориально-понятийного аппарата юриспруденции в решении профессиональных задач (ОПК-3.в.1)',
#    '- способами и приемами толкования норм права (ОПК-3.в.4)',
#    '- навыками профессиональной квалификации выявленных в сфере профессиональной и служебной деятельности фактов и обстоятельств (ОПК-3.в.5)']},
#  'ОПК-4': {'knowledge': ['- порядок организации документирования и документооборота с учетом сферы своей профессиональной деятельности (ОПК-4.з.1)',
#    '- порядок составления и оформления процессуальных и служебных документов (ОПК-4.з.2)'],
#   'abilities': ['- правильно составлять и оформлять процессуальные и служебные документы связанные с профессиональной деятельностью (ОПК-4.у.1)'],
#   'ownerships': []},
#  'ОПК-5': {'knowledge': ['- законодательство Российской Федерации, нормы материального и процессуального права, сущность и содержание основных понятий, категорий, институтов, правовых статусов субъектов, правоотношений субъектов правоотношений (ОПК-5.з.1)',
#    '- формы и способы реализации норм права, механизм правового регулирования (ОПК-5.з.2)'],
#   'abilities': ['- собирать, анализировать и оценивать информацию, имеющую значение для реализации правовых норм, устанавливать фактические обстоятельства, имеющие юридическое значение, определять характер правоотношения и правовые нормы, подлежащие применению при принятии юридически обоснованного решения, принимать юридически значимые решения и совершать юридические действия в соответствии с законом (ОПК-5.у.1)'],
#   'ownerships': ['- навыками сбора, анализа и оценки информации, имеющей значение для реализации правовых норм; навыками принятия юридически значимых решений, отвечающих требованиям действующего законодательства (ОПК-5.в.1)']},
#  'ОПК-6': {'knowledge': ['- положения действующего законодательства Российской Федерации в области обеспечения законности и правопорядка (ОПК-6.з.1)',
#    '- способы установления фактических обстоятельств, имеющих юридическое значение при решении задач профессиональной деятельности (ОПК-6.з.3)'],
#   'abilities': ['- правильно толковать и квалифицированно применять положения нормативных правовых актов (ОПК-6.у.3)',
#    '- принимать юридические решения в соответствии с законодательством Российской Федерации (ОПК-6.у.4)',
#    '- выполнять должностные обязанности по обеспечению законности и правопорядка (ОПК-6.у.6)'],
#   'ownerships': []},
#  'ОПК-7': {'knowledge': ['- задачи по выявлению, предупреждению, пресечению и раскрытию преступлений и иных правонарушений (ОПК-7.з.1)',
#    '- порядок приема, регистрации и документального оформления сообщения о преступлении (ОПК-7.з.2)',
#    '- производство по делам об административных правонарушениях (ОПК-7.з.4)'],
#   'abilities': ['- принимать и регистрировать все сообщения о правонарушениях, преступлениях и происшествиях (ОПК-7.у.1)',
#    '- документировать действия лиц, совершивших преступление и иные правонарушения (ОПК-7.у.2)',
#    '- получать, анализировать и оценивать оперативно-значимую информацию, способствующую выявлению, предупреждению, пресечению и раскрытию преступлений и иных правонарушений (ОПК-7.у.3)'],
#   'ownerships': ['- навыком обеспечения безопасности граждан и общественной безопасности (ОПК-7.в.1)']},
#  'ОПК-11': {'knowledge': ['- основы профилактики, предупреждения правонарушений, организационно-правовые средства их обеспечения (ОПК-11.з.2)'],
#   'abilities': ['- выявлять причины и условия, способствующие различным видам правонарушений (ОПК-11.у.1)',
#    '- планировать и своевременно осуществлять мероприятия по предупреждению, профилактике правонарушений (ОПК-11.у.2)'],
#   'ownerships': ['- навыками выявления и устранения причин и условий, способствующих совершению преступлений (ОПК-11.в.1)',
#    '- навыками применения средств предупреждения, профилактики правонарушений (ОПК-11.в.2)']},
#  'ПК-1': {'knowledge': [],
#   'abilities': ['- анализировать юридические факты нарушения прав и свобод человека и гражданина, и возникающие в связи с этим правовые отношения, правильно составлять и оформлять процессуальные документы (ПК-1.у.1)'],
#   'ownerships': ['- навыками принятия необходимых мер по защите и обеспечению прав человека в процессе профессиональной деятельности сотрудника подразделения по обеспечению безопасности дорожного движения (ПК-1.в.1)',
#    '- навыками защиты прав, свобод и интересов в случае нарушения таковых (ПК-1.в.2)']},
#  'ПК-2': {'knowledge': ['- виды и назначение нарядов полиции при чрезвычайных обстоятельствах (ПК-2.з.2)',
#    '- задачи, правовые основы и порядок действий ОВД при решении задач в особых условиях, чрезвычайных обстоятельствах чрезвычайных ситуациях, условиях режима чрезвычайного положения и в военное время (ПК-2.з.3)'],
#   'abilities': [],
#   'ownerships': []},
#  'ПК-4': {'knowledge': ['- основания и порядок применения физической силы, специальных средств и огнестрельного оружия в случаях и порядке, предусмотренных Федеральным законом от 7 февраля 2011 г. № 3-ФЗ «О полиции» (ПК-4.з.1)'],
#   'abilities': ['- выявлять факты нарушения прав и законных интересов граждан при применении специальных мер принуждения (ПК-4.у.2)'],
#   'ownerships': []},
#  'ПК-5': {'knowledge': [],
#   'abilities': [],
#   'ownerships': ['- навыками процессуального оформления материалов дел об административных правонарушениях (ПК-5.в.1)']},
#  'ПК-6': {'knowledge': ['- порядок и тактику применения физической силы, специальных средств и огнестрельного оружия при задержании правонарушителей, а также в условиях крайней необходимости и необходимой самообороны (ПК-6.з.1)'],
#   'abilities': [],
#   'ownerships': []},
#  'ПК-19': {'knowledge': ['- формы и методы организации деятельности строевых подразделений дорожно-патрульной службы Государственной инспекции безопасности дорожного движения Министерства внутренних дел Российской Федерации (ПК-19.з.1)'],
#   'abilities': [],
#   'ownerships': ['- навыками выявления нарушений Правил дорожного движения и других нормативов, действующих в области дорожного движения (ПК-19.в.1)']},
#  'ПК-29': {'knowledge': ['- порядок и тактику применения мер обеспечения производства по делам об административных правонарушениях в области дорожного движения (ПК-29.з.1)'],
#   'abilities': ['- применять меры обеспечения производства по делам об административных правонарушениях в области дорожного движения (ПК-29.у.1)'],
#   'ownerships': ['- навыками применения мер обеспечения производства по делам об административных правонарушениях в области дорожного движения (ПК-29.в.1)']},
#  'ПК-30': {'knowledge': ['- алгоритм квалификации состава административного правонарушения в сфере безопасности дорожного движения (ПК-30.з.2)'],
#   'abilities': ['- квалифицировать состав административного правонарушения в сфере безопасности дорожного движения (ПК-30.у.1)'],
#   'ownerships': ['- навыками квалификации составов административных правонарушений в сфере безопасности дорожного движения (ПК-30.в.1)']},
#  'ПК-31': {'knowledge': ['- порядок рассмотрения и принятия решения по обращениям граждан при производстве по делу об административном правонарушении (ПК-31.з.1)'],
#   'abilities': ['- правильно составлять и оформлять служебные и процессуальные документы, связанные с рассмотрением и принятием решения по обращениям граждан при производстве по делу об административном правонарушении (ПК-31.у.1)'],
#   'ownerships': []},
#  'ПК-44': {'knowledge': ['- профессиональные задачи, реализуемые в процессе осуществления деятельности подразделений по обеспечению безопасности дорожного движения (ПК-44.з.1)'],
#   'abilities': [],
#   'ownerships': []}}

# %%
# Удаление содержания всех компетенций из программ и связей в учебном плане, создание программ если их нет

for disc in plan.disciplines.keys():
    wp = WorkProgram(disc)
    wp.comp_data_del()
    plan.disciplines_comp_del(disc)

# %%
# Проверка соответствия дисциплин в плане и матрице

for disc in plan.disciplines.keys():
    disc_name = plan.discipline_name(disc)
    if matrix.disc_check(disc_name) is False:
        print (disc_name, 'не найдена в матрице')
        
# Дописать "не найдена в плане"

# %%
# получение ID компетенций плана для дисциплины для загрузки

# for disc in plan.disciplines.keys():

def disc_load_ids(curriculum_discipline_id):
    disc_comp_load = []
    disc_name = plan.discipline_name(curriculum_discipline_id)
    comp_data = matrix.disc_comp(disc_name)
    for comp in comp_data:
        for v in range(len(plan.competencies)):
            if comp == plan.competencies[v]['code']:
                disc_comp_load.append(plan.competencies[v]['id'])
    return disc_comp_load

# %%
disc_load_ids(10464)
# Out:
# ['4115', '4116', '4117', '4137', '4139', '4140', '4149']

# %%
# Загрузка компетенций для дисциплин в план (создание связей)

for disc in plan.disciplines.keys():
    for comp in disc_load_ids(disc):
        plan.disciplines_comp_load(disc, comp)

# %%
# Загрузка индикаторов в программу

def work_program_load(curriculum_discipline_id):
    wp = WorkProgram(curriculum_discipline_id)
    wp.comp_data_del()
    disc_name = plan.discipline_name(curriculum_discipline_id)
    comp_data = matrix.disc_comp(disc_name)
    fields = {1:'knowledge', 2:'abilities', 3:'ownerships'}
    knowledge, abilities, ownerships = [], [], []

    for comp in comp_data.keys():
        for v in range(len(plan.competencies)):
            if comp == plan.competencies[v]['code']:
                competency_id = plan.competencies[v]['id']
                for f in fields:
                    value = (';\n').join(comp_data[comp][fields[f]])
                    if value:
                        wp.comp_data_add(competency_id, f, value)

        knowledge += comp_data[comp]['knowledge']
        abilities += comp_data[comp]['abilities']
        ownerships += comp_data[comp]['ownerships']

    wp.comp_level_edit((';\n').join(knowledge), (';\n').join(knowledge), (';\n').join(knowledge))

# %%
for disc in plan.disciplines.keys():
    work_program_load(disc)

# %%
db_filter_req('mm_work_programs_competencies_data', 'work_program_id', 3229)
# Out:
# [{'id': '19808',
#   'work_program_id': '3229',
#   'competency_id': '4115',
#   'field_id': '2',
#   'value': '- осуществлять поиск информации, необходимой для решения задач профессиональной деятельности; выделять главную информацию; подвергать сомнению достоверность информации (УК-1.у.1);\n- сопоставлять предметы и явления с целью нахождения общих и частных характеристик; разделять объект (процесс) на составные части в целях выявления различных его сторон, свойств и отношений; соединять выделенные в процессе анализа части, признаки, свойства и отношения объекта (процесса) (УК-1.у.2);\n- выявлять закономерности и взаимосвязи; устанавливать объективную истину; обосновывать выбранные пути решения задач профессиональной деятельности (УК-1.у.3)'},
#  {'id': '19809',
#   'work_program_id': '3229',
#   'competency_id': '4115',
#   'field_id': '3',
#   'value': '- способностью применять системный подход при решении проблемных ситуаций и выработке стратегии действий в профессиональной деятельности (УК-1.в.1)'},
#  {'id': '19810',
#   'work_program_id': '3229',
#   'competency_id': '4116',
#   'field_id': '1',
#   'value': '- способы постановки цели и определения в ее рамках круга задач (УК-2.з.2)'},
#  {'id': '19811',
#   'work_program_id': '3229',
#   'competency_id': '4116',
#   'field_id': '2',
#   'value': '- формулировать в рамках поставленной цели проекта совокупность взаимосвязанных задач, обеспечивающих ее достижение (УК-2.у.1);\n- проектировать решение конкретной задачи проекта, выбирать оптимальный способ ее решения, исходя из действующих правовых норм и имеющихся ресурсов и ограничений (УК-2.у.3)'},
#  {'id': '19812',
#   'work_program_id': '3229',
#   'competency_id': '4116',
#   'field_id': '3',
#   'value': '- способностью определять ожидаемые результаты решения выделенных задач (УК-2.в.1)'},
#  {'id': '19813',
#   'work_program_id': '3229',
#   'competency_id': '4117',
#   'field_id': '1',
#   'value': '- особенности поведения выделенных групп людей, с которыми работает (взаимодействует), учитывает их в своей деятельности (УК-3.з.1)'},
#  {'id': '19814',
#   'work_program_id': '3229',
#   'competency_id': '4117',
#   'field_id': '2',
#   'value': '- предвидеть результаты (последствия) личных действий и планировать последовательность шагов для достижения заданного результата (УК-3.у.1);\n- эффективно взаимодействовать с другими членами команды, в том числе участвовать в обмене информацией, знаниями и опытом, и презентации результатов работы команды (УК-3.у.2)'},
#  {'id': '19815',
#   'work_program_id': '3229',
#   'competency_id': '4137',
#   'field_id': '1',
#   'value': '- основные методы и средства сбора, хранения, поиска, систематизации, обработки, передачи информации; состав, функции и возможности аппаратно-программного обеспечения; понятия информационной сферы, информационных технологий, использование информационных технологий в правоохранительной деятельности и перспективы их развития; основные методы, способы и средства защиты информации; назначение, функции и возможности профессионально-ориентированных справочных информационно-правовых и информационно-поисковых систем; роль и место мобильных систем в решении профессиональных задач (ОПК-12.з.1)'},
#  {'id': '19816',
#   'work_program_id': '3229',
#   'competency_id': '4137',
#   'field_id': '2',
#   'value': '- эффективно использовать компьютерную технику при решении служебных задач; использовать локальные и глобальные ресурсы компьютерных сетей для решения служебных задач; самообучаться в современных компьютерных средах; организовывать свое автоматизированное рабочее место (ОПК-12.у.1)'},
#  {'id': '19817',
#   'work_program_id': '3229',
#   'competency_id': '4137',
#   'field_id': '3',
#   'value': '- навыками компьютерной обработки служебной документации, статистической информации и деловой графики; практическими методами работы с информационными системами и базами данных, используемыми в профессиональной деятельности (ОПК-12.в.1)'},
#  {'id': '19818',
#   'work_program_id': '3229',
#   'competency_id': '4139',
#   'field_id': '1',
#   'value': '- задачи, правовые основы и порядок действий ОВД при решении задач в особых условиях, чрезвычайных обстоятельствах чрезвычайных ситуациях, условиях режима чрезвычайного положения и в военное время (ПК-2.з.3)'},
#  {'id': '19819',
#   'work_program_id': '3229',
#   'competency_id': '4140',
#   'field_id': '1',
#   'value': '- порядок осуществления телекоммуникационного, технико-криминалистического и специального технического обеспечения оперативно-служебной деятельности подразделений по обеспечению безопасности дорожного движения (ПК-3.з.1)'},
#  {'id': '19820',
#   'work_program_id': '3229',
#   'competency_id': '4140',
#   'field_id': '2',
#   'value': '- использовать в процессе профессиональной деятельности оперативно-справочные, розыскные, криминалистические и иные формы учетов (ПК-3.у.2)'},
#  {'id': '19821',
#   'work_program_id': '3229',
#   'competency_id': '4140',
#   'field_id': '3',
#   'value': '- навыками осуществления телекоммуникационного, технико-криминалистического и специального технического обеспечения оперативно-служебной деятельности подразделений по обеспечению безопасности дорожного движения (ПК-3.в.1)'},
#  {'id': '19822',
#   'work_program_id': '3229',
#   'competency_id': '4149',
#   'field_id': '1',
#   'value': '- порядок формирования автоматизированных учетов разыскиваемых транспортных средств, утраченных, похищенных регистрационных и иных документов и передачи соответствующей информации (ПК-12.з.1)'},
#  {'id': '19823',
#   'work_program_id': '3229',
#   'competency_id': '4149',
#   'field_id': '2',
#   'value': '- пользоваться базами автоматизированных учетов разыскиваемого автомототранспорта, утраченных, похищенных регистрационных и иных документов, и спецпродукции Госавтоинспекции (ПК-12.у.1)'},
#  {'id': '19824',
#   'work_program_id': '3229',
#   'competency_id': '4149',
#   'field_id': '3',
#   'value': '- навыками формирования автоматизированных учетов разыскиваемых транспортных средств, утраченных, похищенных регистрационных и иных документов (ПК-12.в.1)'}]
